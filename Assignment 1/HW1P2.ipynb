# %%
import pandas as pd

df = pd.read_csv(r'D:\Purdue\SecAna\Assignment 1 attached files Sep 8, 2022 540 PM\adult.data.csv', index_col=None)

# %%
print(df.head(3))
print(df.columns)
# Out:
#    age          workclass   fnlwgt   education   education-num  \
# 0   39          State-gov    77516   Bachelors              13
# 1   50   Self-emp-not-inc    83311   Bachelors              13
# 2   38            Private   215646     HS-grad               9
#
#         marital-status          occupation    relationship    race    sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White   Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White   Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White   Male
#
#     capital-gain   capital-loss   hours-per-week  native-country  salary
# 0           2174              0               40   United-States   <=50K
# 1              0              0               13   United-States   <=50K
# 2              0              0               40   United-States   <=50K
# Index(['age', ' workclass', ' fnlwgt', ' education', ' education-num',
# ...

# %%
male = len(df[df[" sex"] == ' Male'])
print(f"The number of male memebers are {male}")
female = len(df[df[' sex'] == ' Female'])
print(f"The number of female memebers are {female}")
# Out:
# The number of male memebers are 21790
# The number of female memebers are 10771

# %%
dfw = df[df[' sex']==' Female']
avg_age_w = dfw['age'].mean()
print(f"The average age of women is {avg_age_w:.2f}")
# Out:
# The average age of women is 36.86

# %%
german = len(df[df[' native-country']==' Germany'])
#print(german)
df.groupby(" native-country").size()
perc = german/(len(df)-583)
perc = perc*100
print(f"The percentage of germans is {perc:.2f}")
# Out:
# The percentage of germans is 0.43

# %%
dfg50 = df[df[' salary']==' >50K']
dfl50 = df[df[' salary']==' <=50K']
print(f"The mean and standard deviation of age for people earning more than 50K are {dfg50['age'].mean():.2f} and {dfg50['age'].std():.2f}")
print(f"The mean and standard deviation of age for people earning less than 50K are {dfl50['age'].mean():.2f} and {dfl50['age'].std():.2f}")
# Out:
# The mean and standard deviation of age for people earning more than 50K are 44.25 and 10.52
# The mean and standard deviation of age for people earning less than 50K are 36.78 and 14.02

# %%
dfg50.groupby(" education").size()
print("No it's not true. Some do not have high school education")
# Out:
# No it's not true. Some do not have high school education

# %%
dfr = df.groupby(" race")
dfr["age"].describe()
# Out:
#                        count       mean        std   min   25%   50%   75%  \
#  race
#  Amer-Indian-Eskimo    311.0  37.173633  12.447130  17.0  28.0  35.0  45.5
#  Asian-Pac-Islander   1039.0  37.746872  12.825133  17.0  28.0  36.0  45.0
#  Black                3124.0  37.767926  12.759290  17.0  28.0  36.0  46.0
#  Other                 271.0  33.457565  11.538865  17.0  25.0  31.0  41.0
#  White               27816.0  38.769881  13.782306  17.0  28.0  37.0  48.0
#
#                       max
#  race
#  Amer-Indian-Eskimo  82.0
#  Asian-Pac-Islander  90.0
#  Black               90.0
#  Other               77.0
#  White               90.0

# %%
dfg = df.groupby(' sex')
dfg["age"].describe()
# Out:
#            count       mean        std   min   25%   50%   75%   max
#  sex
#  Female  10771.0  36.858230  14.013697  17.0  25.0  35.0  46.0  90.0
#  Male    21790.0  39.433547  13.370630  17.0  29.0  38.0  48.0  90.0

# %%
dfh = df[' hours-per-week']
print(f"The maximum no. of hours a person works per week is {dfh.max()}")
print(f"The number of persons that work {dfh.max()} hours per week is {len(dfh[dfh == dfh.max()])}")
print(f"The percentage of people earning more than 50K is {(len(dfg50[dfg50[' hours-per-week'] == 99])*100/len(dfh[dfh == dfh.max()])):.2f}")
# Out:
# The maximum no. of hours a person works per week is 99
# The number of persons that work 99 hours per week is 85
# The percentage of people earning more than 50K is 29.41

# %%
dfc = dfg50.groupby(" native-country")
dfc[" hours-per-week"].describe()
# Out:
#                       count       mean        std   min    25%   50%    75%  \
#  native-country
#  ?                    146.0  45.547945  10.202827   8.0  40.00  40.0  50.00
#  Cambodia               7.0  40.000000   0.000000  40.0  40.00  40.0  40.00
#  Canada                39.0  45.641026  12.066673  20.0  40.00  45.0  51.00
#  China                 20.0  38.900000  10.125008  10.0  38.00  40.0  41.25
#  Columbia               2.0  50.000000   0.000000  50.0  50.00  50.0  50.00
#  Cuba                  25.0  42.440000  12.453514  14.0  40.00  40.0  50.00
#  Dominican-Republic     2.0  47.000000   9.899495  40.0  43.50  47.0  50.50
#  Ecuador                4.0  48.750000   2.500000  45.0  48.75  50.0  50.00
#  El-Salvador            9.0  45.000000   7.071068  35.0  40.00  45.0  50.00
#  England               30.0  44.533333  11.072592  20.0  40.00  40.0  50.00
#  France                12.0  50.750000  16.360290  40.0  40.00  47.5  50.00
# ...

# %%
dfc = dfl50.groupby(" native-country")
dfc[" hours-per-week"].describe()
# Out:
#                                count       mean        std   min    25%   50%  \
#  native-country
#  ?                             437.0  40.164760  12.817002   1.0  40.00  40.0
#  Cambodia                       12.0  41.416667   3.088346  40.0  40.00  40.0
#  Canada                         82.0  37.914634  13.012056   8.0  32.75  40.0
#  China                          55.0  37.381818  11.439844   1.0  36.00  40.0
#  Columbia                       57.0  38.684211   8.610952   5.0  40.00  40.0
#  Cuba                           70.0  37.985714   9.960055   5.0  40.00  40.0
#  Dominican-Republic             68.0  42.338235  11.121594  22.0  40.00  40.0
#  Ecuador                        24.0  38.041667  10.251105  22.0  30.00  40.0
#  El-Salvador                    97.0  36.030928   9.396867   3.0  32.00  40.0
#  England                        60.0  40.483333  15.177472   7.0  40.00  40.0
#  France                         17.0  41.058824  12.401969  15.0  40.00  40.0
# ...

# %%
print(f"The average number of hours people earning more than 50k work in Japan is 47.95")
print(f"The average number of hours people earning less than 50k work in Japan is 41.0")
# Out:
# The average number of hours people earning more than 50k work in Japan is 47.95
# The average number of hours people earning less than 50k work in Japan is 41.0
